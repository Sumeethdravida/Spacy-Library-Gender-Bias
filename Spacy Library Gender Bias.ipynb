# %%
import spacy

nlp = spacy.load("en_core_web_md")

# %%
doc = nlp("dog cat banana sumeeth")

# %%
for token in doc:
    print(token.text, "Vector:", token.has_vector, token.is_oov)
# Out:
# dog Vector: True False
# cat Vector: True False
# banana Vector: True False
# sumeeth Vector: False True

# %%
doc[3].vector.shape
# Out:
# (300,)

# %%
base = nlp("bread")
d = nlp("Tiger Peacock Sumeeth Manchester Bun Milk")

for token in d:
    print(f"{token.text} <-> {base.text}", token.similarity(base))
# Out:
# Tiger <-> bread -0.17885291437026693
# Peacock <-> bread -0.20226323292021323
# Sumeeth <-> bread 0.0
# Manchester <-> bread 0.06983805114453281
# Bun <-> bread 0.4228061006664627
# Milk <-> bread 0.23312185594798265
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9472\2766242562.py:5: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   print(f"{token.text} <-> {base.text}", token.similarity(base))

# %%
import numpy as np

# %%
def print_similarity(base_word, words_to_compare):
    base_token = nlp(base_word)
    compare = nlp(words_to_compare)
    for token in compare:
        print(f"{token.text} <-> {base_token.text}", token.similarity(base_token))

# %%
Man_Sim = [print_similarity("Man", "Hero Brave Knowledge Football Battle War Sport Cook Strong Stupid Evil Work Good Intelligent Smart Ignorant Villain Lazy Fear Imbecile")]
# Out:
# Hero <-> Man 0.41596388336633
# Brave <-> Man 0.3696005854628523
# Knowledge <-> Man 0.04533703264198479
# Football <-> Man 0.002228627890475548
# Battle <-> Man 0.12165462653608816
# War <-> Man 0.10897626520321702
# Sport <-> Man 0.04583521574515556
# Cook <-> Man 0.1066903275338135
# Strong <-> Man 0.20806296390963858
# Stupid <-> Man 0.27255632643468874
# Evil <-> Man 0.4151772674495917
# Work <-> Man 0.1835973489257222
# Good <-> Man 0.15249608821192262
# Intelligent <-> Man -0.0026381375965135404
# Smart <-> Man 0.09241269705817515
# Ignorant <-> Man 0.023817983163879272
# Villain <-> Man 0.3643687974085498
# Lazy <-> Man 0.4214304900738113
# Fear <-> Man 0.3408106374719186
# Imbecile <-> Man 0.10529165756900959

# %%
Man_Val = [0.41596388336633, 0.3696005854628523, 0.04533703264198479, 0.002228627890475548, 0.12165462653608816, 0.10897626520321702, 0.04583521574515556, 0.1066903275338135, 0.20806296390963858,0.27255632643468874, 0.4151772674495917, 0.1835973489257222, 0.15249608821192262, -0.0026381375965135404, 0.09241269705817515, 0.023817983163879272, 0.3643687974085498, 0.4214304900738113, 0.3408106374719186, 0.10529165756900959 ]

# %%
type(Man_Val)
# Out:
# list

# %%
Woman = print_similarity("Woman", "Hero Brave Knowledge Football Battle War Sport Cook Strong Stupid Evil Work Good Intelligent Smart Ignorant Villain Lazy Fear Imbecile")
# Out:
# Hero <-> Woman 0.4310546556680313
# Brave <-> Woman 0.36587412278638926
# Knowledge <-> Woman 0.16683488958957396
# Football <-> Woman 0.04708092379866803
# Battle <-> Woman 0.14081887282628014
# War <-> Woman 0.14329194593140807
# Sport <-> Woman 0.06920673963507472
# Cook <-> Woman 0.16038217179195952
# Strong <-> Woman 0.3124946965778799
# Stupid <-> Woman 0.23904512022174704
# Evil <-> Woman 0.3629484970397609
# Work <-> Woman 0.3217117828935784
# Good <-> Woman 0.22588733285728899
# Intelligent <-> Woman 0.12051514611630862
# Smart <-> Woman 0.11057004683769374
# Ignorant <-> Woman 0.001170208097371101
# Villain <-> Woman 0.2236973610361128
# Lazy <-> Woman 0.38640005400916133
# Fear <-> Woman 0.35156120891486636
# Imbecile <-> Woman 0.004080026189439387

# %%
Woman_Val =[0.4310546556680313, 0.36587412278638926, 0.16683488958957396, 0.04708092379866803, 0.14081887282628014, 0.14329194593140807, 0.06920673963507472, 0.16038217179195952, 0.3124946965778799, 0.23904512022174704, 0.3629484970397609, 0.3217117828935784, 0.22588733285728899, 0.12051514611630862, 0.11057004683769374, 0.001170208097371101, 0.2236973610361128, 0.38640005400916133, 0.35156120891486636, 0.004080026189439387]

# %%
print_similarity("Gay", "Hero Brave Knowledge Football Battle War Sport Cook Strong Stupid Evil Work Good Intelligent Smart Ignorant Villain Lazy Fear Imbecile")
# Out:
# Hero <-> Gay 0.18700732752756294
# Brave <-> Gay 0.22316783802945545
# Knowledge <-> Gay 0.06022812798824644
# Football <-> Gay 0.1581064898088902
# Battle <-> Gay 0.05341960116089235
# War <-> Gay 0.06175885874372857
# Sport <-> Gay 0.13807037723073035
# Cook <-> Gay 0.16211069805063896
# Strong <-> Gay 0.20919646207306272
# Stupid <-> Gay 0.16301527522256823
# Evil <-> Gay 0.09082574668517071
# Work <-> Gay 0.18057439896311947
# Good <-> Gay 0.17386205116125145
# Intelligent <-> Gay 0.018220428722378043
# Smart <-> Gay 0.05875143543670945
# Ignorant <-> Gay -0.09604362920955628
# Villain <-> Gay -0.02908230046791115
# Lazy <-> Gay 0.29570239472936427
# Fear <-> Gay 0.2373376656615265
# Imbecile <-> Gay -0.05675182075367886

# %%
Gay_Val =[0.18700732752756294, 0.22316783802945545, 0.06022812798824644, 0.1581064898088902, 0.05341960116089235, 0.06175885874372857, 0.13807037723073035, 0.16211069805063896, 0.20919646207306272, 0.16301527522256823, 0.09082574668517071, 0.18057439896311947, 0.17386205116125145, 0.018220428722378043, 0.05875143543670945, -0.09604362920955628, -0.02908230046791115, 0.29570239472936427, 0.2373376656615265, -0.05675182075367886]

# %%
print_similarity("Lesbian", "Hero Brave Knowledge Football Battle War Sport Cook Strong Stupid Evil Work Good Intelligent Smart Ignorant Villain Lazy Fear Imbecile")
# Out:
# Hero <-> Lesbian 0.18700732752756294
# Brave <-> Lesbian 0.22316783802945545
# Knowledge <-> Lesbian 0.06022812798824644
# Football <-> Lesbian 0.1581064898088902
# Battle <-> Lesbian 0.05341960116089235
# War <-> Lesbian 0.06175885874372857
# Sport <-> Lesbian 0.13807037723073035
# Cook <-> Lesbian 0.16211069805063896
# Strong <-> Lesbian 0.20919646207306272
# Stupid <-> Lesbian 0.16301527522256823
# Evil <-> Lesbian 0.09082574668517071
# Work <-> Lesbian 0.18057439896311947
# Good <-> Lesbian 0.17386205116125145
# Intelligent <-> Lesbian 0.018220428722378043
# Smart <-> Lesbian 0.05875143543670945
# Ignorant <-> Lesbian -0.09604362920955628
# Villain <-> Lesbian -0.02908230046791115
# Lazy <-> Lesbian 0.29570239472936427
# Fear <-> Lesbian 0.2373376656615265
# Imbecile <-> Lesbian -0.05675182075367886

# %%
Lesb_Val = [0.18700732752756294, 0.22316783802945545, 0.06022812798824644, 0.1581064898088902, 0.05341960116089235, 0.06175885874372857, 0.13807037723073035, 0.16211069805063896, 0.20919646207306272, 0.16301527522256823, 0.09082574668517071, 0.18057439896311947, 0.17386205116125145, 0.018220428722378043, 0.05875143543670945, -0.09604362920955628, -0.02908230046791115, 0.29570239472936427, 0.2373376656615265, -0.05675182075367886]

# %%
print_similarity("Transgender", " Hero Brave Knowledge Football Battle War Sport Cook Strong Stupid Evil Work Good Intelligent Smart Ignorant Villain Lazy Fear Imbecile")
# Out:
#   <-> Transgender 0.0
# Hero <-> Transgender 0.24329602811638434
# Brave <-> Transgender 0.19506911817999167
# Knowledge <-> Transgender 0.557395302707118
# Football <-> Transgender 0.16801482172468468
# Battle <-> Transgender 0.14015148751501333
# War <-> Transgender 0.123794841059634
# Sport <-> Transgender 0.2534989081115128
# Cook <-> Transgender 0.12838970023854324
# Strong <-> Transgender 0.4391853519023934
# Stupid <-> Transgender 0.04443121955856712
# Evil <-> Transgender 0.16527293296922146
# Work <-> Transgender 0.4074234732596891
# Good <-> Transgender 0.1463366264832134
# Intelligent <-> Transgender 0.4242313144274201
# Smart <-> Transgender 0.2803114434470798
# Ignorant <-> Transgender 0.10790444610453927
# Villain <-> Transgender 0.04656871999968808
# Lazy <-> Transgender 0.05181437464181457
# Fear <-> Transgender 0.256166700033692
# Imbecile <-> Transgender -0.23655830673193665
# ...

# %%
Trans_Val = [0.24329602811638434, 0.19506911817999167, 0.557395302707118, 0.16801482172468468, 0.14015148751501333, 0.123794841059634, 0.2534989081115128, 0.12838970023854324, 0.4391853519023934, 0.04443121955856712, 0.16527293296922146, 0.4074234732596891, 0.1463366264832134, 0.4242313144274201, 0.2803114434470798, 0.10790444610453927, 0.04656871999968808, 0.05181437464181457, 0.256166700033692, -0.23655830673193665]

# %%
import pandas as pd

Mann = pd.DataFrame(Man_Val, columns=["Straight Man"], index = ["Hero", "Brave", "Knowledge", "Football", "Battle", "War", "Sport", "Cook", "Strong", "Stupid", "Evil", "Work", "Good", "Intelligent", "Smart", "Ignorant", "Villain", "Lazy", "Fear", "Imbecile"])

# %%
Mann
# Out:
#              Straight Man
# Hero             0.415964
# Brave            0.369601
# Knowledge        0.045337
# Football         0.002229
# Battle           0.121655
# War              0.108976
# Sport            0.045835
# Cook             0.106690
# Strong           0.208063
# Stupid           0.272556
# Evil             0.415177
# Work             0.183597
# Good             0.152496
# Intelligent     -0.002638
# Smart            0.092413
# Ignorant         0.023818
# Villain          0.364369
# Lazy             0.421430
# Fear             0.340811
# Imbecile         0.105292

# %%
Womann = pd.DataFrame(Woman_Val, columns=["Straight Woman"], index = ["Hero", "Brave", "Knowledge", "Football", "Battle", "War", "Sport", "Cook", "Strong", "Stupid", "Evil", "Work", "Good", "Intelligent", "Smart", "Ignorant", "Villain", "Lazy", "Fear", "Imbecile"])

# %%
Womann
# Out:
#              Straight Woman
# Hero               0.431055
# Brave              0.365874
# Knowledge          0.166835
# Football           0.047081
# Battle             0.140819
# War                0.143292
# Sport              0.069207
# Cook               0.160382
# Strong             0.312495
# Stupid             0.239045
# Evil               0.362948
# Work               0.321712
# Good               0.225887
# Intelligent        0.120515
# Smart              0.110570
# Ignorant           0.001170
# Villain            0.223697
# Lazy               0.386400
# Fear               0.351561
# Imbecile           0.004080

# %%
Gayy = pd.DataFrame(Gay_Val, columns=["Gay"], index = ["Hero","Brave", "Knowledge", "Football", "Battle", "War", "Sport", "Cook", "Strong", "Stupid", "Evil", "Work", "Good", "Intelligent", "Smart", "Ignorant", "Villain", "Lazy", "Fear", "Imbecile"])

# %%
Gayy
# Out:
#                   Gay
# Hero         0.187007
# Brave        0.223168
# Knowledge    0.060228
# Football     0.158106
# Battle       0.053420
# War          0.061759
# Sport        0.138070
# Cook         0.162111
# Strong       0.209196
# Stupid       0.163015
# Evil         0.090826
# Work         0.180574
# Good         0.173862
# Intelligent  0.018220
# Smart        0.058751
# Ignorant    -0.096044
# Villain     -0.029082
# Lazy         0.295702
# Fear         0.237338
# Imbecile    -0.056752

# %%
Lesbb = pd.DataFrame(Lesb_Val, columns=["Lesbian"], index = ["Hero","Brave", "Knowledge", "Football", "Battle", "War", "Sport", "Cook", "Strong", "Stupid", "Evil", "Work", "Good", "Intelligent", "Smart", "Ignorant", "Villain", "Lazy", "Fear", "Imbecile"])

# %%
Lesbb
# Out:
#               Lesbian
# Hero         0.187007
# Brave        0.223168
# Knowledge    0.060228
# Football     0.158106
# Battle       0.053420
# War          0.061759
# Sport        0.138070
# Cook         0.162111
# Strong       0.209196
# Stupid       0.163015
# Evil         0.090826
# Work         0.180574
# Good         0.173862
# Intelligent  0.018220
# Smart        0.058751
# Ignorant    -0.096044
# Villain     -0.029082
# Lazy         0.295702
# Fear         0.237338
# Imbecile    -0.056752

# %%
Transs = pd.DataFrame(Trans_Val, columns=["Transgeder"], index = ["Hero","Brave", "Knowledge", "Football", "Battle", "War", "Sport", "Cook", "Strong", "Stupid", "Evil", "Work", "Good", "Intelligent", "Smart", "Ignorant", "Villain", "Lazy", "Fear", "Imbecile"])

# %%
Transs
# Out:
#              Transgeder
# Hero           0.243296
# Brave          0.195069
# Knowledge      0.557395
# Football       0.168015
# Battle         0.140151
# War            0.123795
# Sport          0.253499
# Cook           0.128390
# Strong         0.439185
# Stupid         0.044431
# Evil           0.165273
# Work           0.407423
# Good           0.146337
# Intelligent    0.424231
# Smart          0.280311
# Ignorant       0.107904
# Villain        0.046569
# Lazy           0.051814
# Fear           0.256167
# Imbecile      -0.236558

# %%
Lib_Bias = pd.concat([Mann, Womann, Gayy, Lesbb, Transs], axis=1)

# %%
Lib_Bias
# Out:
#              Straight Man  Straight Woman       Gay   Lesbian  Transgeder
# Hero             0.415964        0.431055  0.187007  0.187007    0.243296
# Brave            0.369601        0.365874  0.223168  0.223168    0.195069
# Knowledge        0.045337        0.166835  0.060228  0.060228    0.557395
# Football         0.002229        0.047081  0.158106  0.158106    0.168015
# Battle           0.121655        0.140819  0.053420  0.053420    0.140151
# War              0.108976        0.143292  0.061759  0.061759    0.123795
# Sport            0.045835        0.069207  0.138070  0.138070    0.253499
# Cook             0.106690        0.160382  0.162111  0.162111    0.128390
# Strong           0.208063        0.312495  0.209196  0.209196    0.439185
# Stupid           0.272556        0.239045  0.163015  0.163015    0.044431
# Evil             0.415177        0.362948  0.090826  0.090826    0.165273
# Work             0.183597        0.321712  0.180574  0.180574    0.407423
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

# %%
Lib_Bias.plot(kind="bar", figsize=(10,10))
plt.title("NLP Spacy Library Gender Bias")
plt.xlabel("Words in the english language and its gender association")
plt.ylabel("Association value for each gender \n Multiply by 100 for percentage \n For example, the association of the word Hero for Men is about 41% and for Women is about 43% \n and the association of the word Intelligent for Men is about -0.2% and for Transgenders is about 42%")
# Out:
# Text(0, 0.5, 'Association value for each gender \n Multiply by 100 for percentage \n For example, the association of the word Hero for Men is about 41% and for Women is about 43% \n and the association of the word Intelligent for Men is about -0.2% and for Transgenders is about 42%')

# %%
plt.savefig("output.jpg")

# %%
positive_words = Lib_Bias.loc[['Hero','Brave', 'Knowledge', 'Strong', 'Good', 'Intelligent', 'Smart']]

# %%
positive_words
# Out:
#              Straight Man  Straight Woman       Gay   Lesbian  Transgeder
# Hero             0.415964        0.431055  0.187007  0.187007    0.243296
# Brave            0.369601        0.365874  0.223168  0.223168    0.195069
# Knowledge        0.045337        0.166835  0.060228  0.060228    0.557395
# Strong           0.208063        0.312495  0.209196  0.209196    0.439185
# Good             0.152496        0.225887  0.173862  0.173862    0.146337
# Intelligent     -0.002638        0.120515  0.018220  0.018220    0.424231
# Smart            0.092413        0.110570  0.058751  0.058751    0.280311

# %%
Mean_All = pd.DataFrame(columns=["Mean of Positive Words"],data = positive_words.mean())

# %%
Mean_All
# Out:
#                 Mean of Positive Words
# Straight Man                  0.183034
# Straight Woman                0.247604
# Gay                           0.132919
# Lesbian                       0.132919
# Transgeder                    0.326546

# %%
Mean_All.plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.pie(Mean_All['Mean of Positive Words'], autopct='%.2f%%', labels=Mean_All.index )
# Out:
# ([<matplotlib.patches.Wedge at 0x1811a2af910>,
# ...
#  [Text(0.9307653130002473, 0.5862388012709084, 'Straight Man'),
#   Text(-0.3394624455142502, 1.0463103020067637, 'Straight Woman'),
#   Text(-1.0956925115699303, 0.09725183848945053, 'Gay'),
#   Text(-0.8212786659258929, -0.731779579446561, 'Lesbian'),
#   Text(0.5917485860311444, -0.92727213423576, 'Transgeder')],
#  [Text(0.5076901707274075, 0.31976661887504093, '17.89%'),
#   Text(-0.1851613339168637, 0.5707147101855073, '24.20%'),
#   Text(-0.5976504608563256, 0.0530464573578821, '12.99%'),
#   Text(-0.4479701814141234, -0.39915249787994234, '12.99%'),
#   Text(0.3227719560169879, -0.5057848004922327, '31.92%')])

# %%
Describe = Lib_Bias.describe().transpose()
Describe
# Out:
#                 count      mean       std       min       25%       50%  \
# Straight Man     20.0  0.189684  0.149717 -0.002638  0.080768  0.137075
# Straight Woman   20.0  0.209231  0.132943  0.001170  0.118029  0.195266
# Gay              20.0  0.114474  0.104022 -0.096044  0.057418  0.148088
# Lesbian          20.0  0.114474  0.104022 -0.096044  0.057418  0.148088
# Transgeder       20.0  0.197135  0.174844 -0.236558  0.119822  0.166644
#
#                      75%       max
# Straight Man    0.346700  0.421430
# Straight Woman  0.329174  0.431055
# Gay             0.182183  0.295702
# Lesbian         0.182183  0.295702
# Transgeder      0.262203  0.557395

# %%
Describe = Describe.reset_index()
Describe
# Out:
#             index  count      mean       std       min       25%       50%  \
# 0    Straight Man   20.0  0.189684  0.149717 -0.002638  0.080768  0.137075
# 1  Straight Woman   20.0  0.209231  0.132943  0.001170  0.118029  0.195266
# 2             Gay   20.0  0.114474  0.104022 -0.096044  0.057418  0.148088
# 3         Lesbian   20.0  0.114474  0.104022 -0.096044  0.057418  0.148088
# 4      Transgeder   20.0  0.197135  0.174844 -0.236558  0.119822  0.166644
#
#         75%       max
# 0  0.346700  0.421430
# 1  0.329174  0.431055
# 2  0.182183  0.295702
# 3  0.182183  0.295702
# 4  0.262203  0.557395

# %%
sns.barplot(Describe, x = Describe['index'], y=Describe['std'])
# Out:
# <Axes: xlabel='index', ylabel='std'>

# %%
sns.barplot(Describe, x=Describe['index'], y=Describe['mean'])
# Out:
# <Axes: xlabel='index', ylabel='mean'>

# %%
Lib_Bias.corr()
# Out:
#                 Straight Man  Straight Woman       Gay   Lesbian  Transgeder
# Straight Man        1.000000        0.873597  0.484245  0.484245   -0.191574
# Straight Woman      0.873597        1.000000  0.711179  0.711179    0.230002
# Gay                 0.484245        0.711179  1.000000  1.000000    0.242919
# Lesbian             0.484245        0.711179  1.000000  1.000000    0.242919
# Transgeder         -0.191574        0.230002  0.242919  0.242919    1.000000

# %%
sns.heatmap(Lib_Bias.corr(), annot = True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
negative_words = pd.DataFrame(Lib_Bias.loc[["Stupid", "Evil", "Ignorant", "Villain", "Lazy", "Fear", "Imbecile"]])

# %%
negative_words
# Out:
#           Straight Man  Straight Woman       Gay   Lesbian  Transgeder
# Stupid        0.272556        0.239045  0.163015  0.163015    0.044431
# Evil          0.415177        0.362948  0.090826  0.090826    0.165273
# Ignorant      0.023818        0.001170 -0.096044 -0.096044    0.107904
# Villain       0.364369        0.223697 -0.029082 -0.029082    0.046569
# Lazy          0.421430        0.386400  0.295702  0.295702    0.051814
# Fear          0.340811        0.351561  0.237338  0.237338    0.256167
# Imbecile      0.105292        0.004080 -0.056752 -0.056752   -0.236558

# %%
negative_words.plot(kind='bar')
# Out:
# <Axes: >

# %%
N_Describe = negative_words.describe().transpose()
N_Describe
# Out:
#                 count      mean       std       min       25%       50%  \
# Straight Man      7.0  0.277636  0.155596  0.023818  0.188924  0.340811
# Straight Woman    7.0  0.224129  0.163400  0.001170  0.113889  0.239045
# Gay               7.0  0.086429  0.152531 -0.096044 -0.042917  0.090826
# Lesbian           7.0  0.086429  0.152531 -0.096044 -0.042917  0.090826
# Transgeder        7.0  0.062229  0.152895 -0.236558  0.045500  0.051814
#
#                      75%       max
# Straight Man    0.389773  0.421430
# Straight Woman  0.357255  0.386400
# Gay             0.200176  0.295702
# Lesbian         0.200176  0.295702
# Transgeder      0.136589  0.256167

# %%
plt.pie(N_Describe['mean'], autopct='%.2f%%', labels=N_Describe.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1811c67a450>,
# ...
#  [Text(0.4152398932310823, 1.0186146627009842, 'Straight Man'),
#   Text(-1.0819491096194276, -0.1984593766838141, 'Straight Woman'),
#   Text(-0.07179091524695046, -1.097654802061197, 'Gay'),
#   Text(0.684528167834217, -0.8610581788947423, 'Lesbian'),
#   Text(1.0615112071251487, -0.2884336269364409, 'Transgeder')],
#  [Text(0.22649448721695392, 0.5556079978369004, '37.68%'),
#   Text(-0.590154059792415, -0.10825056910026223, '30.42%'),
#   Text(-0.03915868104379116, -0.5987208011242892, '11.73%'),
#   Text(0.3733790006368456, -0.46966809757895034, '11.73%'),
#   Text(0.5790061129773537, -0.1573274328744223, '8.45%')])

# %%
N_Describe = N_Describe.reset_index()

# %%
sns.barplot(N_Describe, x=N_Describe['index'], y=N_Describe['mean'] )
# Out:
# <Axes: xlabel='index', ylabel='mean'>

# %%
neutral_words = pd.DataFrame(Lib_Bias.loc[["Football", "Battle", "War", "Sport","Cook", "Work"]])

# %%
neutral_words
# Out:
#           Straight Man  Straight Woman       Gay   Lesbian  Transgeder
# Football      0.002229        0.047081  0.158106  0.158106    0.168015
# Battle        0.121655        0.140819  0.053420  0.053420    0.140151
# War           0.108976        0.143292  0.061759  0.061759    0.123795
# Sport         0.045835        0.069207  0.138070  0.138070    0.253499
# Cook          0.106690        0.160382  0.162111  0.162111    0.128390
# Work          0.183597        0.321712  0.180574  0.180574    0.407423

# %%
neutral_words.plot(kind='bar')
# Out:
# <Axes: >

# %%
neutral_describe = neutral_words.describe().transpose()
neutral_describe
# Out:
#                 count      mean       std       min       25%       50%  \
# Straight Man      6.0  0.094830  0.063112  0.002229  0.061049  0.107833
# Straight Woman    6.0  0.147082  0.096738  0.047081  0.087110  0.142055
# Gay               6.0  0.125673  0.054503  0.053420  0.080837  0.148088
# Lesbian           6.0  0.125673  0.054503  0.053420  0.080837  0.148088
# Transgeder        6.0  0.203546  0.110771  0.123795  0.131330  0.154083
#
#                      75%       max
# Straight Man    0.118485  0.183597
# Straight Woman  0.156110  0.321712
# Gay             0.161110  0.180574
# Lesbian         0.161110  0.180574
# Transgeder      0.232128  0.407423

# %%
neutral_describe = neutral_describe.reset_index()

# %%
plt.pie(neutral_describe['mean'], autopct='%.2f%%', labels = neutral_describe['index'] )
# Out:
# ([<matplotlib.patches.Wedge at 0x1811d96f110>,
# ...
#  [Text(1.0009830654506273, 0.45610624056360527, 'Straight Man'),
#   Text(0.057798076090461795, 1.0984804879469827, 'Straight Woman'),
#   Text(-1.015876234982894, 0.4218950997546425, 'Gay'),
#   Text(-0.8126218385930302, -0.7413809732126144, 'Lesbian'),
#   Text(0.6684135425046471, -0.8736265427494683, 'Transgeder')],
#  [Text(0.5459907629730694, 0.24878522212560283, '13.61%'),
#   Text(0.031526223322070064, 0.5991711752438087, '21.11%'),
#   Text(-0.5541143099906695, 0.23012459986616862, '18.04%'),
#   Text(-0.4432482755961982, -0.4043896217523351, '18.04%'),
#   Text(0.3645892050025347, -0.4765235687724372, '29.21%')])

# %%
sns.barplot(neutral_describe, x=neutral_describe['index'], y=neutral_describe['std'])
# Out:
# <Axes: xlabel='index', ylabel='std'>
